# %%
import pandas as pd
import numpy as np
import os
import pickle
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
file_path = '../프로젝트csv/naver평점.csv'
movies = pd.read_csv('../프로젝트csv/movie_df.csv')

# %%
movie_title = movies['MOVIE_NM'].unique()
print(len(movie_title)),print(movie_title)
# Out:
# 2579
# ['소울' '극장판 귀멸의 칼날: 무한열차편' '원더 우먼 1984' ... '열 개의 우물' '아가미'
#  '뉴클래식 프로젝트 미안하다, 사랑한다']
# (None, None)

# %%
# 동적 웹 크롤링으로 평점 받아오기 (naver)
def naver_crawling_grade(grade_non_list, file_path):
    dv = webdriver.Chrome()
    dv.get('http://www.naver.com')
    time.sleep(3)
    el = dv.find_element(By.CSS_SELECTOR, 'input#query')
    
    try:
        movie = pd.read_csv(file_path)
    except :
        movie = pd.DataFrame({'MOVIE_NM': movie_title})
        
    for title in grade_non_list :
        el.clear()
        el.send_keys('영화 {} 평점'.format(title))
        el.send_keys(Keys.ENTER)
        time.sleep(3)
        
        try :
            grades = dv.find_element(By.CSS_SELECTOR, 'span.area_star_number')
            grade = grades.text
            grade = round(float(grade), 2)
            
        except :
            grade = np.nan
            
        movie.loc[movie['MOVIE_NM']==title, '네이버_평점'] = grade
        
        el = dv.find_element(By.CSS_SELECTOR, 'input#nx_query')
    
    dv.close()
    movie.to_csv(file_path, index=False, encoding='utf-8')
    print(f"네이버 평점 업데이트 완료! {file_path}에 저장되었습니다.")

# %%
naver_crawling_grade(movie_title, file_path)
movie = pd.read_csv(file_path)
movie.sample(50)
# Out:
# 네이버 평점 업데이트 완료! ../프로젝트csv/naver평점.csv에 저장되었습니다.
#                         MOVIE_NM  네이버_평점
# 1714               뮤지컬 더 데빌 2018     NaN
# 31                          사일런싱    6.03
# 2064  매직 프린세스: 얼음 괴물과 사라진 열쇠의 비밀    3.42
# 2476                  래시: 뉴 어드벤처   10.00
# 348    신비아파트 뮤지컬 시즌3 : 뱀파이어왕의 비밀    0.00
# 1240                          큐브    5.51
# 2008            극장판 파워 디지몬 더 비기닝    5.44
# 1449    극장판 뽀로로와 친구들: 바이러스를 없애줘!    8.43
# 450                        프리 가이    8.47
# 194                    고질라 VS. 콩    8.89
# 220                     유어 아이즈 텔    9.54
# 580                       영화의 거리    8.17
# 1391                      본즈 앤 올    8.02
# 669                 피치 오브 타임 극장판    7.52
# 1853           살바도르 달리 : 불멸을 찾아서    6.53
# 1912                         칸다하    7.20
# 1213                 적인걸: 천안의 비밀    0.00
# 1816                    몸값part.1    9.25
# 2451     레드불 T1 다큐멘터리 : 함께 날아오르다    8.52
# 2412                     이오 카피타노    8.11
# 2179                    유어 럭키 데이    6.33
# 635        매직 스쿨: 초보마법사 아우라의 대모험    5.62
# 372                         보더라인     NaN
# 248    BBC프롬스: 그라치니테-틸라와 버밍엄 심포니     NaN
# 2069                       홈그라운드    8.14
# 2352       명탐정 코난: 100만 달러의 펜타그램    8.06
# 2132                   두 세계 사이에서    7.70
# 1364                       선데이리그     NaN
# 1264                  금의위: 용의 비검    0.00
# 1597                    이니셰린의 밴시    8.30
# 1217                        비상선언    6.25
# 176      라스칼라 갈라 콘서트: 별들을 다시 보려고    9.80
# 2121                  정글번치: 월드투어    7.88
# 336                         슈퍼노바     NaN
# 221                         아수라도    9.60
# 660                       가족의 색깔    7.14
# 886             미결처리반 Q: 침묵의 암살자    8.00
# 324                        파이프라인     NaN
# 1459                    페르시아어 수업    8.21
# 1881                         라모나    0.00
# 1032                  그리스도 디 오리진    7.27
# 1421                  에브리띵 윌 체인지    7.75
# 692                귀멸의 칼날: 남매의 연    7.21
# 2291                    오늘부터 댄싱퀸    7.76
# 1232                   베르히만 아일랜드    7.66
# 513                          캐논볼    8.09
# 464               스페이스 잼: 새로운 시대    7.00
# 2174                    서바이벌 택틱스    8.58
# 857            극장판 천재 추리 탐정 셜록홈즈    8.83
# 1122                    버즈 라이트이어    7.40
