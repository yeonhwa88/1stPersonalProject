# %%
import pandas as pd
import numpy as np
import os
import pickle
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
file_path = 'result/movie_cine21.csv'
movie = pd.read_csv('result/movie.csv')

# %%
movie_title = set(movie['MOVIE_NM'])
print(len(movie_title)),print(movie_title)
# Out:
# 2580
# {'더 배트맨', '프로메어', '달짝지근해: 7510', '신 테니스의 왕자 효테이 vs 릿카이 : 게임 오브 퓨처 후편', '117편의 러브레터', '문재인입니다', '이스케이프 런', '리프레쉬', '열대왕사', '버스납치', '나의 행복한 결혼', '당신은 학생인가', '배우의 꿈', '파티마의 기적', '핑크퐁과 아기상어의 월드투어쇼', '흐르다', '쏜애플 불구경 2024 라이브 콘서트 필름', '말아', '킬러 하이드', '극장판 포켓몬스터 뮤츠의 역습 EVOLUTION', '극장판 츠루네: 시작의 한 발', '청킹맨션', '웬디고: 전설의 몬스터', '단순한 열정', '아기상어 극장판: 사이렌 스톤의 비밀', '종착역', '극장판 금빛 모자이크 땡큐!!', '겨울밤에', '대무가', '몸값part.1', '말하고 싶은 비밀', '엄마의 땅: 그리샤와 숲의 주인', '신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~', '언포기버블', '프랑스', '극장판 엄마 까투리: 도시로 간 까투리 가족', '인플루엔자', '아톰 새로운 시작', '싱크홀', '적인걸: 천안의 비밀', 'FBI: 마약전쟁', '나는 나대로 혼자서 간다', '립세의 사계', '스페이스 잼: 새로운 시대', '내가 처음으로 사랑한 소녀', '오지: 사라진 숲을 찾아서', '아침바다 갈매기는', '헤이지니&럭키강이 비밀의 문', '그 남자, 좋은 간호사', '콘크리트 유토피아', '하나님의 마음', '킹 오브 킬러스', '소피의 세계', '보이지 않아', '폴리스', '엑소시스트: 더 데빌', '라라의 신비한 모험', '에브리띵 윌 체인지', '메이드 인 아메리카', '화이트 온 화이트', '아바타 리마스터링', '정직한 후보2', '리볼버 릴리', '보통의 카스미', '가족은 괴로워3: 아내여 장미처럼', '열여덟, 어른이 되는 나이', '블랙 위도우', '나의 사소한 슬픔', '콰이어트 플레이스 2', '금의위4 지존무사', 'EBS친구들 씽씽 댄스파티', '육지것들', '극장판 실바니안 패밀리: 프레야의 선물', '히트맨: 코드네임 버튜소', '당신의 사월', '웅남이', '극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021', '레일로드 워', '라스트 버스', '유공자', '레드불 T1 다큐멘터리 : 함께 날아오르다', '이터널 로드', '적호서생', '캔디맨', '액션동자', '다크 앤드 위키드', '지옥만세', '메이드 인 이태리', '국카스텐 콘서트 실황 : 해프닝', 'FBI 데스트랩', '거미집', '극장판 후르츠 바스켓: 프렐류드', '아이엠 티라노', '카일리 블루스', '극장판 엉덩이 탐정: 수플레 섬의 비밀', '슈퍼 마리오 브라더스', '사고물건 무서운 방', '양성인간', '그리고 방행자', '딸에 대하여', '아노라', '수색자', '유코의 평형추', '1947 보스톤', '어웨이', '인시디어스: 빨간 문', '시라노', '나는 마을 방과후 교사입니다', '나비효과', '길위에 김대중', '픽션들', '귀공자', '아야와 마녀', '머릿속을', '이누부!', '어쌔신 게임', '간신의 피', '300: 전사의 귀환', '샤인', '큰엄마의 미친봉고', '공기살인', '프로이트의 라스트 세션', '극장판 시그널', '괴담만찬', '스티브 맥퀸: 더 맨 앤 르망', '독친', '서바이벌리스트', '바바리안', '칙 파이트', '킬러의 보디가드 2: 킬러의 와이프', '부활: 그 증거', '그녀가 죽었다', '너와 사랑한 시간', '파리, 13구', '팟 제너레이션', '그림자라 불리는 남자들', '한번 죽어 봤다', "주세페 베르디의 '레퀴엠'", '더 챔피언', '래시 컴 홈', '뉴클래식 프로젝트 미안하다, 사랑한다', '파벨만스', '언더그라운드', '러브 어페어: 우리가 말하는 것, 우리가 하는 것', '햄릿', '고질라 X 콩: 뉴 엠파이어', '라스트 나잇 인 소호', '마브카 : 숲의 노래', '극장판 소드 아트 온라인 -프로그레시브- 짙은 어둠의 스케르초', '챌린저스', '메간', '티탄', '파이어하트', '크루아상', '만천과해', '전쟁', '가재가 노래하는 곳', '대전투 1944', '와일드캣', '창가의 토토', '당신은 믿지 않겠지만', '우리는 천국에 갈 순 없지만 사랑은 할 수 있겠지', '피어: 마지막 생존자', '드림빌더', '그리고, 살아간다', '컴백트레일', '올드', '아이돌레시피', '브로커', '안나푸르나', '용루각2: 신들의 밤', '자메이카의 소울: 이나 데 야드', '마더스', '던전 앤 드래곤: 도적들의 명예', '쿠사마 야요이: 무한의 세계', '기동전사 건담 시드 프리덤', '세버그', '왓츠 러브', '쿠폰의 여왕', '랜드 오브 배드', '사형에 이르는 병', '레전더리 콘서트: 레너드 번스타인', '극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아', '배드 럭 뱅잉', '스마일 2', '옥스포드 살인사건', '겨울 이야기', '무한궤도 (가면속의 거짓말)', '이어지는 땅', '52헤르츠 고래들', '센티그레이드', '뉴 노멀', '클럽 제로', '되살아나는 목소리', '세상 참 예쁜 오드리', '스펜서', '물꽃의 전설', '한여름밤의 재즈', '탄생', '디베르티멘토', '안녕, 할부지', '룩백', '재즈처럼 더 무비', '갓길로 달리는 코뿔소', '헬 카운트', '청춘 18X2 너에게로 이어지는 길', '여타짜', '삼총사', '솔져스 리벤지', '교섭', '워 위드 그랜파', '브루스 윌리스의 라스트 미션: 데이 투 다이', '드림쏭3', '미션 임파서블: 데드 레코닝 PART ONE', '포에버 퍼스트 러브', '돌들이 말할 때까지', '찬란한 내일로', '이름 없는 춤', '스트레인저스: 챕터1', '쏘우 X', '고백', '악이 도사리고 있을 때', '아이윌 송', '감동주의보', '그 남자는 타이타닉을 보고 싶지 않았다', '명탐정코난: 하이바라 아이 이야기 ~흑철의 미스터리 트레인', '영화의 거리', '맨 온 엣지', '남은 인생 10년', "요루시카 '달과 고양이의 댄스' 2024 라이브", '익스파이어드', '브라더', '로보카폴리 안전교실 교통편', '글래디에이터: 레전드 워리어', '플레이 뮤지컬 핑크퐁과 아기상어의 생일파티 대소동', '숏버스 섬뜩행', '에반게리온 신극장판: 서', '피닉스', '해길랍', '트리거 포인트', '천국에서 무덤까지', '극장판 겁쟁이 페달', '낫아웃', '크라이오', '2067', '비올레타', '성적유희의 극한적 경험', '천지열혈 양가장', '썰', '오늘 밤, 세계에서 이 사랑이 사라진다 해도', '엄마', '멋진 세계', '더 납작 엎드릴게요', '여섯 개의 밤', '애프터: 유혹의 끝', '룸 넥스트 도어', '안티고네', '공작조: 현애지상', '타다: 대한민국 스타트업의 초상', '더블패티', 'B컷', '김준수 콘서트 무비 챕터 원 : 레크리에이션', '스페이스 키드: 우주에서 살아남기', '정국: 아이 엠 스틸 위드 유', '노트르담', '첫번째 아이', '늑대들', '악마의 부활', '렛 미 고', '극장판 검정고무신 : 즐거운 나의 집', '사비나: 그리스도를 위한 고난, 나치 시대', '에브리씽 에브리웨어 올 앳 원스', '자기만의 방', '올 더 네임즈 오브 갓', '물은 바다를 향해 흐른다', '엔드리스', 'BBC프롬스: 거슈윈 영화 음악 콘서트', '그대 너머에', '광대: 소리꾼', '리본', '그대들은 어떻게 살 것인가', '대한민국 대통령', '마지막 대전투: 전장의 영웅들', '이웃사촌', '오글리스: 웰컴 투 냄새 마을', '아네모네', '와일드 마운틴 타임', '내겐 너무 소중한 너', '몽키킹5 절대신공', '화녀', '올리 마키의 가장 행복한 날', '정복자 윌리엄', '타임 이즈 업', '원티드 킬러', '십계', '2023 심규선 단독 콘서트 : 우리 앞의 세계', '스크림', '어메이징 모리스', '도뷔시', '잃어버린 얼굴 1895', '모르는 이야기', '나이트 레이더스', '더 커버넌트', '스피릿',  ...
# (None, None)

# %%
# 동적 웹 크롤링으로 평점 받아오기 (cene21)
def cene21_crawling_grade(grade_non_list, file_path):
    dv = webdriver.Chrome()
    dv.get('http://www.cine21.com/')
    time.sleep(1.5)
    el = dv.find_element(By.CSS_SELECTOR, 'input.input_search')
    
    try:
        movie = pd.read_csv(file_path)
    except :
        movie = pd.DataFrame({'MOVIE_NM': movie_title})
        
    for title in grade_non_list :
        el.clear()
        el.send_keys('{}'.format(title))
        el.send_keys(Keys.ENTER)
        time.sleep(1.5)
        
        try :
            grades = dv.find_element(By.CSS_SELECTOR, 'span.num')
            grade = grades.text
            grade = round(float(grade), 2)
            
        except :
            grade = np.nan
            
        movie.loc[movie['MOVIE_NM']==title, '씨네21_평점'] = grade
        
        el = dv.find_element(By.CSS_SELECTOR, 'input.input_search')
    
    dv.close()
    movie.to_csv(file_path, index=False, encoding='utf-8')
    print(f"씨네21 평점 업데이트 완료! {file_path}에 저장되었습니다.")

# %%
cene21_crawling_grade(movie_title, file_path)
movie = pd.read_csv(file_path)
movie.sample(50)
# Out:
# 씨네21 평점 업데이트 완료! result/movie_cine21.csv에 저장되었습니다.
#        NO                    MOVIE_NM              DRCTR_NM  \
# 5654   11                         리볼버                   오승욱
# 1711  193                    첫눈이 사라졌다  마우고시카 슈모프스카,마셀 엔그레르트
# 4805   35                          비밀               임경호,소준범
# 736    75  극장판 바다 탐험대 옥토넛 : 불의 고리 대폭발                   NaN
# 5429   86                       도그데이즈                   김덕민
# 5502   59                     퀸 엘리자베스                 로저 미첼
# 2948   29                          성덕                   오세연
# 1902   34              우리가 사랑이라고 믿는 것               윌리엄 니콜슨
# 5698   55            극장판 : 기븐_히이라기 믹스                   NaN
# 863    72                      나만 보이니                   임용재
# 914   126                 카발레리아 루스티카나                   NaN
# 5013    9                         데드맨                   하준원
# 2085   77                   하우스 오브 구찌                리들리 스콧
# 462    50           국카스텐 콘서트 실황 : 해프닝                   NaN
# 4749   99                        세일즈걸          생게도르지 잔치브로드지
# 5578   35             그랑블루 오리지날 리마스터링                  뤽 베송
# 4494  106         에릭 클랩튼: 어크로스 24 나이츠              데이비드 바나드
# 245   140                     데스 오브 미             대런 린 보우즈만
# 4171   45       가디언즈 오브 갤럭시: Volume 3                 제임스 건
# 4725   75               치치핑핑의 쿵쿵따 탐험대                   이광범
# 2115  110                    끝없음에 관하여               로이 안데르손
# 5109  105                    유어 럭키 데이                   NaN
# 3794   63                     여섯 개의 밤                   최창환
# 4870  100                      물꽃의 전설                   고희영
# 4845   75                    스즈메의 문단속               신카이 마코토
# 5002  118                 룩앳미 터치미 키스미   호 유항,제나르 마에사 아유,김태식
# 5078   74                         K스쿨                   박미경
# 2970   51              은하철도 999 - 극장판                  린 타로
# 2694   21                   뿌까의 짜장면파티                   박상용
# 2210   72                   고양이들의 아파트                   정재은
# 6022   79               더러운 돈에 손대지 마라                   김민수
# 674    13                       미드나이트                   권오승
# 698    37                          애플             크리스토스 니코우
# 4022   35                슈가: 로드 투 디데이                   박준수
# 4532    1                         30일                   남대중
# 2666  135                    소리없는 추격자                   NaN
# 4683   32                     원 모어 찬스                   반요명
# 5359   16        꼬마참새 리차드: 신비한 보석 탐험대                   NaN
# 1835  126           노아의 방주 2: 새로운 세계로                 토비 젠켈
# 634   115                         해길랍                   채밀결
# 1802   92                     좀비 살아있다                 글렌 밀러
# 2256  122                          곡녀                   정인철
# 6002   59          백현: 론스달라이트 닷 인 시네마               오윤동,김하민
# 4014   27                 자우림, 더 원더랜드                김지환,허민
# 4698   47     극장판 우당탕탕 은하안전단: 진정한 용기!                   정지훈
# 3114   58                          초선                   전후석
# 212    90                   그리고, 살아간다                츠키카와 쇼
# 899   109                       더 나이트                   NaN
# 4887  117                         디셈버                안슐 차우한
# 1570   28                           램              발디마르 요한손
#
#                        MAKR_NM         INCME_CMPNY_NM  \
# 5654                 (주)사나이픽처스                    NaN
# 1711                       NaN           주식회사 모쿠슈라픽쳐스
# 4805                    스튜디오고트                    NaN
# 736                        NaN  (주)얼리버드픽쳐스,와이드 릴리즈(주)
# 5429                 (주)씨제이이엔엠                    NaN
# 5502                       NaN              (주)영화사 진진
# 2948                       해랑사                    NaN
# 1902                       NaN                (주)티캐스트
# 5698                       NaN              스튜디오엘론(주)
# 863               유한회사 영화사 반딧불                    NaN
# 914                        NaN                   일미디어
# 5013     (주)팔레트픽처스,(주)사람엔터테인먼트                    NaN
# 2085                       NaN    유니버설픽쳐스인터내셔널 코리아(유)
# 462                    (주)인터파크                    NaN
# 4749                       NaN                   대성필림
# 5578                       NaN              (유)조이앤시네마
# 4494                       NaN              (주)케빈앤컴퍼니
# 245                        NaN              (주)엔케이컨텐츠
# 4171                       NaN     월트디즈니컴퍼니코리아 유한책임회사
# 4725                    (주)에픽캔                    NaN
# 2115                       NaN                     찬란
# 5109                       NaN              주식회사 풍경소리
# 3794           (주)컬쳐플랫폼,매치컷(주)                    NaN
# 4870                       NaN                    NaN
# 4845                       NaN               (주)미디어캐슬
# 5002                      필름라인                    NaN
# 5078                     강 컨텐츠                    NaN
# 2970                       NaN      (주)에스피오 엔터테인먼트코리아
# 2694                    (주)에픽캔                    NaN
# 2210                     영화사 못                    NaN
# 6022                   리양필름(주)                    NaN
# 674                (주)페퍼민트앤컴퍼니                    NaN
# 698                        NaN           주식회사 모쿠슈라픽쳐스
# 4022                    (주)하이브                    NaN
# 4532                  (주)영화사울림                    NaN
# 2666                       NaN                    NaN
# 4683                       NaN                    NaN
# 5359                       NaN                     찬란
# 1835                       NaN                    NaN
# 634                        NaN                     오드
# 1802                       NaN                    NaN
# 2256                      대성필름                    NaN
# 6002  씨제이포디플렉스 주식회사,스크린엑스 스튜디오                    NaN
# 4014               써티세븐스디그리(주)                    NaN
# 4698                 (주)마로스튜디오                    NaN
# 3114           디아스포라 필름,포핸즈스토리                    NaN
# 212                        NaN               (주)미디어캐슬
# 899                        NaN        브릿지웍스 엔터테인먼트(주)
# 4887                       NaN               (주)미디어캐슬
# 1570                       NaN                     오드
#
#                    DISTB_CMPNY_NM      OPN_DE MOVIE_TY_NM MOVIE_STLE_NM  \
# 5654                  플러스엠 엔터테인먼트    20240807        개봉영화            장편
# 1711                    (주)다자인소프트    2021-10-        개봉영화            장편
# 4805                 (주)영화특별시에스엠씨    20231213        개봉영화            장편
# 736                     주식회사 컨텐츠썬  20210428.0        개봉영화            장편
# 5429                    (주)씨제이이엔엠    20240207        개봉영화            장편
# 5502                    (주)영화사 진진    20240612        개봉영화            장편
# 2948                           오드    2022-09-        개봉영화            장편
# 1902                      (주)티캐스트    2022-02-        개봉영화            장편
# 5698                   (주)팝엔터테인먼트    20240828        개봉영화            장편
# 863                      (주)디스테이션    2021-07-        개봉영화            장편
# 914                          일미디어    2021-07-        개봉영화            장편
# 5013                  플러스엠 엔터테인먼트    20240207        개봉영화            장편
# 2085          유니버설픽쳐스인터내셔널 코리아(유)    2022-01-        개봉영화            장편
# 462                    CGV ICECON    20210324        개봉영화            장편
# 4749                         대성필림    20231115        개봉영화            장편
# 5578      (주)제이앤씨미디어그룹,와이드 릴리즈(주)    20240717        개봉영화            장편
# 4494                    (주)케빈앤컴퍼니    20230823        개봉영화            장편
# 245                     (주)엔케이컨텐츠    20210205        개봉영화            장편
# 4171           월트디즈니컴퍼니코리아 유한책임회사    20230503        개봉영화            장편
# 4725                       (주)에픽캔    20230410        개봉영화            장편
# 2115                           찬란    2021-12-        개봉영화            장편
# 5109                    주식회사 풍경소리    20240222        개봉영화            장편
# 3794                       ㈜인디스토리    20230329        개봉영화            장편
# 4870                    (주)영화사 진진    20230830        개봉영화            장편
# 4845                       (주)쇼박스    20230308        개봉영화            장편
# 5002                       시네마 뉴원    20231206        개봉영화            장편
# 5078                        강 컨텐츠    20240221        개봉영화            장편
# 2970                     (주)디스테이션    2022-10-        개봉영화            장편
# 2694                       (주)에픽캔    2022-07-        개봉영화            장편
# 2210            (주)엣나인필름,(주)메타플레이    2022-03-        개봉영화            장편
# 6022                (주)에이스메이커무비웍스    20241017        개봉영화            장편
# 674           씨제이 씨지브이(CJ CGV)(주)  20210630.0        개봉영화            장편
# 698                     (주)다자인소프트  20210526.0        개봉영화            장편
# 4022       롯데컬처웍스(주)롯시플,(주)영화사 그램    20230616        개봉영화            장편
# 4532                     (주)마인드마크    20231003        개봉영화            장편
# 2666                    (유)조이앤시네마    2022-06-        개봉영화            장편
# 4683                   (주)팝엔터테인먼트    20231101        개봉영화            장편
# 5359                 (주)스튜디오디에이치엘    20240501        개봉영화            장편
# 1835  (주)대교 미디어콘텐츠사업본부,(주)팝엔터테인먼트    2021-12-        개봉영화            장편
# 634                            오드    20210331        개봉영화            장편
# 1802                    (유)조이앤시네마    2022-01-        개봉영화            장편
# 2256                       시네마 뉴원    2022-03-        개봉영화            장편
# 6002      씨제이포디플렉스 주식회사,씨지브이 아이스콘    20241127        개봉영화            장편
# 4014                    메가박스중앙(주)    20230607        개봉영화            장편
# 4698          (주)넥스트엔터테인먼트월드(NEW)    20231130        개봉영화            장편
# 3114                    커넥트픽쳐스(주)    2022-11-        개봉영화            장편
# 212                      (주)미디어캐슬    20210115        개봉영화            장편
# 899                    와이드 릴리즈(주)    2021-07-        개봉영화            장편
# 4887                     (주)미디어캐슬    20231216        개봉영화            장편
# 1570                           오드    2021-12-        개봉영화            장편
#
#      NLTY_NM  ...    SALES_PRICE VIEWNG_NMPR_CO SEOUL_SALES_PRICE  \
# 5654      한국  ...  2,300,008,453        245,683       696,029,366
# 1711     폴란드  ...            NaN            2.0               0.0
# 4805      한국  ...       61960305           6020          30723102
# 736       영국  ...            NaN          467.0               NaN
# 5429      한국  ...      4,128,000            367         2,576,000
# 5502      영국  ...     10,266,839          1,362         7,254,339
# 2948      한국  ...            NaN            NaN               NaN
# 1902      영국  ...            NaN            NaN               NaN
# 5698      일본  ...     26,529,373          2,885        11,589,278
# 863       한국  ...            NaN            NaN               NaN
# 914     이탈리아  ...            NaN          274.0               NaN
# 5013      한국  ...     2257288704         236624         514590306
# 2085      미국  ...            NaN          296.0               NaN
# 462       한국  ...       20094000           1126           4068000
# 4749      몽고  ...        4183039            456           3539039
# 5578     프랑스  ...     41,580,200          4,343        15,739,800
# 4494      영국  ...            NaN          128.0               NaN
# 245       기타  ...         100000             20                 0
# 4171      미국  ...            NaN            NaN               NaN
# 4725      한국  ...        6483000           1066            864000
# 2115      기타  ...            NaN           24.0               NaN
# 5109      미국  ...         492000             82                 0
# 3794      한국  ...            NaN            NaN               NaN
# 4870      한국  ...        2344000            293           2344000
# 4845      일본  ...       10443812            988           7404800
# 5002      한국  ...         184000             19            176000
# 5078      한국  ...        5673900            599           4574000
# 2970      일본  ...            NaN            NaN               NaN
# 2694      한국  ...            NaN            NaN               NaN
# 2210      한국  ...            NaN            NaN               NaN
# 6022      한국  ...      9,729,900          1,439           363,000
# 674       한국  ...            NaN            NaN               NaN
# 698       기타  ...            NaN            NaN               NaN
# 4022      한국  ...            NaN            NaN               NaN
# 4532      한국  ...            NaN            NaN               NaN
# 2666     스페인  ...            NaN           12.0               0.0
# 4683      중국  ...       80597900          13048          24001900
# 5359      독일  ...    273,680,900         35,449        43,081,200
# 1835      독일  ...            NaN           39.0               NaN
# 634       기타  ...         341000             52            341000
# 1802      미국  ...            NaN          205.0               NaN
# 2256      한국  ...            NaN           69.0               NaN
# 6002      한국  ...     91,050,000          3,642        46,800,000
# 4014      한국  ...            NaN            NaN               NaN
# 4698      한국  ...       49444890           6653          18302390
# 3114      한국  ...            NaN            NaN               NaN
# 212       일본  ...        1030570            117            998070
# 899       기타  ...            NaN          490.0               NaN
# 4887      일본  ...         818657            122             40000
# 1570      기타  ...            NaN            NaN               NaN
#
#      SEOUL_VIEWNG_NMPR_CO GENRE_NM   GRAD_NM MOVIE_SDIV_NM 네이버_평점  구글_평점  \
# 5654               69,163       범죄  15세이상관람가          일반영화    NaN    NaN
# 1711                  0.0      판타지  15세이상관람가       독립/예술영화   7.22    NaN
# 4805                 2862     미스터리   청소년관람불가          일반영화    NaN    NaN
# 736                  72.0    애니메이션     전체관람가          일반영화   9.26    NaN
# 5429                  184      드라마  12세이상관람가          일반영화   7.88    NaN
# 5502                  897    다큐멘터리     전체관람가       독립/예술영화   8.78    NaN
# 2948                  NaN    다큐멘터리  12세이상관람가       독립/예술영화    NaN    NaN
# 1902                  NaN      드라마  12세이상관람가       독립/예술영화   8.61    NaN
# 5698                1,179    애니메이션  15세이상관람가          일반영화    NaN    NaN
# 863                 699.0   공포(호러)  15세이상관람가          일반영화   5.09    NaN
# 914                 126.0       공연  12세이상관람가          일반영화   0.00    NaN
# 5013                52144       범죄  15세이상관람가          일반영화   7.88    NaN
# 2085                183.0       범죄  15세이상관람가          일반영화   7.69    NaN
# 462                   226       공연     전체관람가          일반영화    NaN    NaN
# 4749                  386      드라마  15세이상관람가       독립/예술영화   6.67    NaN
# 5578                1,618      드라마  15세이상관람가          일반영화    NaN    NaN
# 4494                 93.0       공연  12세이상관람가          일반영화   9.40    NaN
# 245                     0   공포(호러)   청소년관람불가          일반영화   3.67    NaN
# 4171                  NaN       액션  12세이상관람가          일반영화   9.35    NaN
# 4725                  144       공연     전체관람가          일반영화    NaN    NaN
# 2115                 20.0       기타  12세이상관람가       독립/예술영화   7.25    NaN
# 5109                    0       액션  15세이상관람가       독립/예술영화   6.33    NaN
# 3794                481.0      드라마  12세이상관람가       독립/예술영화   8.09    NaN
# 4870                  293    다큐멘터리     전체관람가       독립/예술영화   8.89    NaN
# 4845                  594    애니메이션  12세이상관람가       독립/예술영화   8.45    NaN
# 5002                   18   멜로/로맨스  15세이상관람가       독립/예술영화  10.00    NaN
# 5078                  484      드라마     전체관람가       독립/예술영화   7.67    NaN
# 2970                  NaN    애니메이션  12세이상관람가       독립/예술영화   8.59    NaN
# 2694                  NaN       기타     전체관람가          일반영화    NaN    NaN
# 2210                716.0    다큐멘터리     전체관람가       독립/예술영화   7.95    NaN
# 6022                   34       범죄  15세이상관람가          일반영화   7.04    NaN
# 674                   NaN      스릴러  15세이상관람가          일반영화    NaN    NaN
# 698                   NaN      드라마  12세이상관람가       독립/예술영화    NaN    NaN
# 4022                  NaN    다큐멘터리  12세이상관람가          일반영화   9.92    NaN
# 4532                  NaN      코미디  12세이상관람가          일반영화   7.99    NaN
# 2666                  0.0     미스터리   청소년관람불가       독립/예술영화   1.50    NaN
# 4683                 3893      드라마  12세이상관람가          일반영화   6.33    NaN
# 5359                5,960    애니메이션     전체관람가       독립/예술영화   6.62    NaN
# 1835                 14.0    애니메이션     전체관람가          일반영화   8.27    NaN
# 634                    52   멜로/로맨스  15세이상관람가       독립/예술영화   7.88    NaN
# 1802                 66.0       액션  15세이상관람가          일반영화   8.31    NaN
# 2256                 20.0      드라마  12세이상관람가       독립/예술영화   5.50    NaN
# 6002                1,872       공연     전체관람가          일반영화   9.47    NaN
# 4014                  NaN    다큐멘터리     전체관람가       독립/예술영화   8.22    NaN
# 4698                 2539    애니메이션     전체관람가          일반영화   8.44    NaN
# 3114                  NaN    다큐멘터리  12세이상관람가       독립/예술영화   8.67    NaN
# 212                   113      드라마  12세이상관람가       독립/예술영화   7.83    NaN
# 899                 265.0   공포(호러)  15세이상관람가       독립/예술영화    NaN    NaN
# 4887                    5      드라마  15세이상관람가       독립/예술영화   7.60    NaN
# 1570                  NaN   공포(호러)  15세이상관람가       독립/예술영화   7.07    NaN
#
#       씨네21_평점
# 5654     4.00
# 1711     6.33
# 4805     4.00
# 736      6.00
# 5429     5.33
# 5502     5.50
# 2948     6.40
# 1902     6.50
# 5698     5.00
# 863      3.00
# 914       NaN
# 5013     5.00
# 2085     6.80
# 462       NaN
# 4749     8.00
# 5578     8.50
# 4494      NaN
# 245      3.00
# 4171     7.40
# 4725      NaN
# 2115     7.00
# 5109      NaN
# 3794     5.75
# 4870     6.00
# 4845     7.60
# 5002     5.00
# 5078     4.00
# 2970     7.17
# 2694      NaN
# 2210     6.80
# 6022     6.00
# 674      3.50
# 698      6.67
# 4022      NaN
# 4532     6.67
# 2666      NaN
# 4683     4.67
# 5359     5.50
# 1835     5.00
# 634      6.00
# 1802      NaN
# 2256     1.00
# 6002      NaN
# 4014     6.00
# 4698     6.00
# 3114     8.00
# 212       NaN
# 899      5.00
# 4887     7.00
# 1570     6.67
#
# [50 rows x 21 columns]
